# %% [markdown]
# # ***MONITOR DE FONDOS***
# ---
# CIERRES

# %% [markdown]
# * chat: https://chatgpt.com/c/6967f48a-edb4-8328-93c8-7f31637a1239
# * Activar venv: .\venv\Scripts\Activate.ps1

# %%
hola

# %%
# paquetes
import streamlit as st

# %%
st.set_page_config(
    page_title="Tarjeta Informativa – Subejercicio 2025",
    layout="wide"
)

st.title("Tarjeta Informativa – Subejercicio 2025")
st.success("Entorno configurado correctamente")
